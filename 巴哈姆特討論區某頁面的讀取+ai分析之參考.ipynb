# %% [markdown]
# <a href="https://colab.research.google.com/github/pupupeter/-/blob/main/%E5%B7%B4%E5%93%88%E5%A7%86%E7%89%B9%E8%A8%8E%E8%AB%96%E5%8D%80%E6%9F%90%E9%A0%81%E9%9D%A2%E7%9A%84%E8%AE%80%E5%8F%96%2Bai%E5%88%86%E6%9E%90%E4%B9%8B%E5%8F%83%E8%80%83.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #給同學一個非PTT版的網頁做參考，這個是來自於巴哈姆特討論區的頁面做爬蟲
#
# 表單:https://docs.google.com/spreadsheets/d/1aumoUUW3Md2K2cc1OLDxGIgvehDojwIll0TeYLZNXb0/edit?usp=sharing
#
# 原網址:https://forum.gamer.com.tw/C.php?page=1&bsn=12259&snA=226091&tnum=34&subbsn=18

# %%
import google.generativeai as genai
import os

api_key = '自己的API'
genai.configure(api_key = api_key)

model = genai.GenerativeModel('gemini-2.0-flash')
response = model.generate_content('打上你要問的問題')

print(response.text)
# Out:
# 請根據我提供的資訊或情境，提出你可以回答的問題。例如：
#
# *   如果你想讓我做翻譯，請提供要翻譯的文本。
# *   如果你想讓我寫文章，請提供主題、風格和字數要求。
# *   如果你想讓我查找資訊，請提供明確的搜尋關鍵字。
# *   如果你想讓我進行計算，請提供算式和單位。
# *   如果你想讓我提供建議，請提供你的情況和需求。
#
# 我需要知道你想讓我做什麼才能回答你的問題。

# %%
# 匯入套件
import requests
from bs4 import BeautifulSoup

# 目標網址
url = "https://forum.gamer.com.tw/C.php?bsn=12259&snA=226091&tnum=34&subbsn=18"

# 設定 headers 模擬瀏覽器
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/122.0.0.0 Safari/537.36"
}

# 發送 GET 請求
response = requests.get(url, headers=headers)

# 確認是否成功
if response.status_code == 200:
    soup = BeautifulSoup(response.text, "html.parser")

    # 找文章內文（巴哈文章通常在 class "c-article__content" 或 "c-article__content-inner"）
    contents = soup.find_all("div", class_="c-article__content")
    if not contents:
        contents = soup.find_all("div", class_="c-article__content-inner")

    # 列出每一段文字
    for i, content in enumerate(contents):
        text = content.get_text(strip=True)
        print(f"--- 文章段落 {i+1} ---")
        print(text)
else:
    print(f"無法存取頁面，狀態碼: {response.status_code}")
# Out:
# --- 文章段落 1 ---
# 今天趁有時間，花了五個小時整理了一下物品中韓文對照表打完才覺得自己怎麼這麼M=口=這些除了能知道什麼東西是什麼之外，最主要還是查看板買賣物品了常常想找物品又臨時找不到關鍵字實在麻煩寵物還有料理跟材料部分我就不多做整理了，實在太多了就是..寵物就只做常時販賣跟常常會查的那幾隻另外這裡也有一樣的文章，都一樣是我整理的，所以不要誤會了！以後出新的東西或許也會更新（？這樣以後找東西就比較方便了▲表示是已絕版物品，無法由製作/副本中再獲得確認文字丟棄버리기刪除삭제하기分解분해하기販售되팔기特殊物品冒險家之證(指南針)새로운 모험의 징표完全恢復藥水완전 회복 포션史詩NPC卡片에픽NPC鬥志藥水투지의 물약精鍊的艾爾結晶엘의 정수職業時裝箱子(7日)프로모션 아바타 큐브 (7일권)武器裝飾品箱子오리하르콘 무기 장식 큐브艾爾積分商店獎勵裝飾品箱子엘 포인트 샵 보너스 액세서리 랜黑暗水晶다크 크리스탈高性能納斯德相機고성능 나소드 카메라公會相關公會硬幣길드 주화公會倉庫擴展券길드창
�福(靈藥)크로노스의 축복(영약)巨人化藥水(靈藥)거인화 물약 (영약)追擊者之魂(靈藥)추적자의 혼 (영약)巨手藥水(靈藥)거대손 물약 (영약)熔炎炸藥(靈藥)이글이글 폭약 (영약)妖精寶寶的搖籃(靈藥)아기 요정 요람 (영약)貝卡多斯的翅膀羽毛(靈藥)벤투스의 날개깃 (영약)羅索的火炎圈(靈藥)로쏘의 화염고리 (영약)丹尼弗的冰晶露(靈藥)데니프의 얼음 구슬 (영약)古代魔龍之爪고대 마룡의 발톱古代魔龍之翼고대 마룡의 날개古代魔龍之尾고대 마룡의 꼬리古代魔龍之帽고대 마룡의 헤드기어古代魔龍之核고대 마룡의 헥사코어魔龍之爪마룡의 발톱魔龍之翼마룡의 날개魔龍之尾마룡의 꼬리魔龍之帽마룡의 헤드기어魔龍之核마룡의 헥사코어巨大Boss系列記憶喪失券기억상실 티켓古代守護石(打洞材料)고대의 수호 광석古代鋼礦石(打洞材料)고대의 강철 광석古代守護神楔(防具打洞)고대의 수호 쐐기古代鋼楔(武器打洞)고대의 강철 쐐기艾特島勇士的項鍊투사의 목걸이勇士的戒指투사의 반지勇士的手環투사의 손등 인장勇士的紋面투사의 전투 문신勇士的武飾투사의 크로니클堅韌的勇士項鍊강인한 투사의 목걸이堅韌的勇士戒指강인한 투사의 반지堅韌的勇士手環강인한 투사의 손등 인장堅韌的勇士紋面강인한 투사의 전투 문신堅韌的勇士武飾강인한 투사의 크로니클共鳴之魔法石(屬性)공명의 마법석法力之魔法石(MP)마나의 마법석強擊之魔法石(增暴雙擊)강타의 마법석副本相關肯塔켄타斯德因스데잉賽蕾娜세이레나伊格妮娅이그니아伊布里坦이플리탄斯卡스카의專職相關下級酏劑하급 엘릭서中級酏劑중급 엘릭서上級酏劑상급 엘릭서祕銀礦石미스릴 원석祕銀碎片미스릴 조각祕銀結晶미스릴 결정上級AP水상급 소생의 포션上級活力藥水상급 활력의 포션藍白蘋果거인의 돌사과紅黃蘋果초인의 유기농 사과綠紫蘋果질풍의 안드로메다 사과上級魔力藥水상급 마나포션上級魔力藥水袋子(20瓶)상급 마나포션 주머니 (20개)最上級魔力藥水최상급 마나포션最 ...
# --- 文章段落 2 ---
# 大大辛苦了。不過我用古歌大溼翻譯出來的有點扯...像是靜止時間的結晶他翻譯成暫停時間和空間的決心艾爾結晶翻成一塊薩爾瓦多的真的好扯...
# --- 文章段落 3 ---
# 安安以下的東西你的物品表沒有的,這是什麼來
# --- 文章段落 4 ---
# 請問 9-5 9-6 的  王飾名稱是什麼?
# --- 文章段落 5 ---
# 생명의 결정 (어둠여우 나호)是九尾暗狐喔
# --- 文章段落 6 ---
# 請問這韓文怎打 我想收尋
# --- 文章段落 7 ---
# 沙德隱藏裝關鍵字打成小金的哦
# --- 文章段落 8 ---
# 因為文字量比較大就不留言直接回覆了抱歉(つд⊂)艾索德：팝핑 머신! 엘소드愛莎：래피드 래퍼! 아이샤蕾娜：천상 보이스! 레나雷文：허스키 보어스! 레이븐EVE：시크 댄서! 이브澄：엔젤 보이스! 청艾拉：글램 바디! 아라愛姐：파워 무브먼트! 엘리시스ADD：펀치 라임! 애드露 / 希爾：퓨어 보이스! 루 / 허니 플로우! 시엘以上是各角色舞者站姿的關鍵字名稱【除了蕾雷澄露的「보어스」外，其餘所有人沒有任何共通詞……】。除了艾愛雷愛姐外都已經測試可用，上述四位大既是因為沒人丟板子所以搜不到，雖然都已核對過字形應該沒錯，但實在不能保證100%正確無誤，如果錯了歡迎蓋鍋_(:3 」∠ )_
# --- 文章段落 9 ---
# 各位好 想請問這個道具的名稱，想換個專職，但是在表格內找不到這個道具在此先感謝幫忙的大大們
# --- 文章段落 10 ---
# 請問這個連身的名稱是什麼？韓版有出過嗎？ 還是只有台版?
# --- 文章段落 11 ---
# 請問白貓手的韓文!? 感謝~
# --- 文章段落 12 ---
# 職裝:전직 프로모션 아바타 티켓(헤어)전직 프로모션 아바타 티켓(상의)這兩個似乎打反了 ..  (헤어)是頭髮 (상의)是下衣
# --- 文章段落 13 ---
# 坐姿 :月的綠色羽翼달의 그린나래 레나 (사파이이어)    藍色달의 그린나래 레나 (오리진)            黃色召喚石:地獄領主소촨석 : 로드 오브 인페르노
# --- 文章段落 14 ---
# 請問FC足球連身裝的韓文是?找了好久都沒找到
# --- 文章段落 15 ---
# 請問這個韓文怎麼打.....
# --- 文章段落 16 ---
# 請問大大,我要高級拆解名加防具可是他好像要我打甚麼東西才能拆請求大大能幫我解答讓我複製文字嗎QQ跪求了~~]
# --- 文章段落 17 ---
# 想問，3/10更新之前的天使套樣三件的韓文，沒有補到。主要想收翅膀，感謝你
# --- 文章段落 18 ---
# 想請問這個眼鏡該怎麼打

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default

creds, _ = default()
gc = gspread.authorize(creds)

SHEET_URL = "https://docs.google.com/spreadsheets/d/1aumoUUW3Md2K2cc1OLDxGIgvehDojwIll0TeYLZNXb0/edit?usp=sharing"
WORKSHEET_NAME = "工作表1"

sh = gc.open_by_url(SHEET_URL)
worksheet = sh.worksheet(WORKSHEET_NAME)

# %%
try:
    worksheet = sh.worksheet(WORKSHEET_NAME)
except gspread.WorksheetNotFound:
    worksheet = sh.add_worksheet(title=WORKSHEET_NAME, rows="1000", cols="3")

# %%
import requests
from bs4 import BeautifulSoup

def crawl_articles(total_pages=2):
    base_url = "https://forum.gamer.com.tw/C.php?bsn=12259&snA=226091&tnum=34&subbsn=18"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                      "AppleWebKit/537.36 (KHTML, like Gecko) "
                      "Chrome/122.0.0.0 Safari/537.36"
    }

    all_text = ""

    for page in range(1, total_pages+1):
        url = f"{base_url}&page={page}"
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            soup = BeautifulSoup(response.text, "html.parser")
            contents = soup.find_all("div", class_="c-article__content")
            if not contents:
                contents = soup.find_all("div", class_="c-article__content-inner")

            for content in contents:
                text = content.get_text(strip=True)
                all_text += f"第 {page} 頁：{text}\n\n"
        else:
            all_text += f"第 {page} 頁無法存取，狀態碼: {response.status_code}\n\n"

    return all_text

# %%
import google.generativeai as genai
import os

api_key = '自己的API'
genai.configure(api_key=api_key)

model = genai.GenerativeModel('gemini-2.5-flash')

def analyze_with_gemini(article_text):
    if not article_text.strip():
        return "沒有抓到文章內容。"

    # 文字過長先截斷
    article_text = article_text[:5000]

    response = model.generate_content(
        f"請幫我分析以下文章內容，提供 3 點重點摘要 + 1 段 100-120 字結論：\n\n{article_text}"
    )

    # 根據回傳物件結構取 text 或 content
    try:
        return response.text
    except AttributeError:
        return response.content

# %%
def save_to_sheet(article_text, ai_summary):
    # 每次新增一列：第一欄原文、第二欄 AI 分析結果
    worksheet.append_row([article_text, ai_summary])
    return "已成功寫入 Google Sheets！"

# %%
crawl_articles(1)
# Out:
# "第 1 頁：今天趁有時間，花了五個小時整理了一下物品中韓文對照表打完才覺得自己怎麼這麼M=口=這些除了能知道什麼東西是什麼之外，最主要還是查看板買賣物品了常常想找物品又臨時找不到關鍵字實在麻煩寵物還有料理跟材料部分我就不多做整理了，實在太多了就是..寵物就只做常時販賣跟常常會查的那幾隻另外這裡也有一樣的文章，都一樣是我整理的，所以不要誤會了！以後出新的東西或許也會更新（？這樣以後找東西就比較方便了▲表示是已絕版物品，無法由製作/副本中再獲得確認文字丟棄버리기刪除삭제하기分解분해하기販售되팔기特殊物品冒險家之證(指南針)새로운 모험의 징표完全恢復藥水완전 회복 포션史詩NPC卡片에픽NPC鬥志藥水투지의 물약精鍊的艾爾結晶엘의 정수職業時裝箱子(7日)프로모션 아바타 큐브 (7일권)武器裝飾品箱子오리하르콘 무기 장식 큐브艾爾積分商店獎勵裝飾品箱子엘 포인트 샵 보너스 액세서리 랜黑暗水晶다크 크리스탈高性能納斯德相機고성능 나소드 카메라公會相關公會硬幣길드 주화公會倉庫擴展券길드창고 확장권公會人數擴展券길드 인원 확장권稱號相關魔力水晶차가운 크리스탈化石碎片고대 화석 조각不滅的鬥志불멸의 투지熱情之手열정의 손길四葉幸運草행운의 네잎크로버混亂詛咒커스 오브 카오스Crayon Pop戰隊稱號크레V용팝異世界的支配者이(異)세계의 지배자材料相關堅固的防具碎片(61~70)억센 방어구 조각堅硬的防具碎片(71~80)단단한 방어구 조각迪西提姆防具碎片(81~90)디시티움 방어구 조각精巧的武器碎片(61~70)정교한 무기 파편鋒利的武器碎片(71~80)날카로운 무기 파편迪西提姆武器碎片(81~90)디시티움 무기 파편閃耀的艾爾結晶(61~70)빛나는 엘의 결정華麗的艾爾結晶(71~80)화려한 엘의 결정晶瑩的艾爾結晶(81~90)영롱한 엘의 결정純淨水(飲料材料)청정수星塵粉末(飲料材料)별 가루榖物粉末(料理材料)곡물 가루露芙草(料理材料)루브 풀結晶系列艾爾結晶엘의 조각艾爾結晶(不明)엘의 조각(불명)艾爾結晶(風)엘의 조각(윈드)艾爾結晶(光)엘의 조각(라이트)艾爾結晶(火)엘의 조각(레드)艾爾結晶(地)엘의 조각(그린)艾爾結晶(闇)엘의 조각(다크)艾爾結晶(水)엘의 조각(블루)強化相關祝福的神聖守護石축복받은 플루오르 스톤祝福的神聖水晶石축복받은 플루오르 수정祝福的復原咒文書축복받은 복원의 주문서祝福的強化石축복받은 강화석▲守護石플루오르 스톤 Lv.▲祝福的復原咒文書축복받은 복원의 주문서 Lv.祝福的時空間咒文書축복받은 시공간의 주문서強化符강화의 부적 Lv.▲武器強化石무기 강화석 Lv.▲防具強化石방어구 강화석 Lv.▲祝福武器強化石축복받은 무기 강화석▲祝福防具強化石축복받은 방어구 강화석魔法石相關魔法石마법석高級魔法石고급 마법석動作速度的魔法石속도의 마법석追加傷害的魔法石추가 데미지의 마법석傷
# %%
import gradio as gr
import gspread
from google.auth import default
import requests
from bs4 import BeautifulSoup
import google.generativeai as genai
import datetime

# ================== Google Sheet Authentication ==================
# This will use the credentials from your environment.
try:
    creds, _ = default()
    gc = gspread.authorize(creds)
except Exception as e:
    print(f"Authentication failed: {e}")
    # Handle the error, maybe by exiting or showing a message in the UI
    raise

# Define sheet URL and worksheet names
SHEET_URL = "https://docs.google.com/spreadsheets/d/1aumoUUW3Md2K2cc1OLDxGIgvehDojwIll0TeYLZNXb0/edit?usp=sharing"
WORKSHEET_NAME_1 = "工作表1"
WORKSHEET_NAME_2 = "工作表2"

# Open the spreadsheet
sh = gc.open_by_url(SHEET_URL)

# Get or create the first worksheet for raw data
try:
    worksheet1 = sh.worksheet(WORKSHEET_NAME_1)
except gspread.WorksheetNotFound:
    worksheet1 = sh.add_worksheet(title=WORKSHEET_NAME_1, rows="1000", cols="3")

# Get or create the second worksheet for analysis results
try:
    worksheet2 = sh.worksheet(WORKSHEET_NAME_2)
except gspread.WorksheetNotFound:
    worksheet2 = sh.add_worksheet(title=WORKSHEET_NAME_2, rows="1000", cols="3")

# ================== Gemini API Configuration ==================
# Note: It is generally safer to load API keys from environment variables
# rather than hardcoding them in the script.
api_key = '自己的API'
genai.configure(api_key=api_key)

# Use a valid and available model, e.g., 'gemini-1.5-flash'
model = genai.GenerativeModel('gemini-2.5-flash')

# ================== Web Scraper Function (修正後) ==================
def crawl_articles(page=1):
    """Crawls a specific page of the forum and returns all article text."""
    base_url = "https://forum.gamer.com.tw/C.php?bsn=12259&snA=226091&tnum=34&subbsn=18"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"
    }
    url = f"{base_url}&page={page}"
    all_text = ""
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Raise an exception for bad status codes

        # ==================【關鍵修正】==================
        # 強制指定使用 UTF-8 編碼來解讀網頁內容
        response.encoding = 'utf-8'
        # ================================================

        # 現在 response.text 會正確地使用 UTF-8 處理
        soup = BeautifulSoup(response.text, "html.parser")

        contents = soup.find_all("div", class_="c-article__content")
        if not contents:
            contents = soup.find_all("div", class_="c-article__content-inner")

        page_content = [content.get_text(strip=True) for content in contents]

        if page_content:
            all_text = "\n\n".join(page_content)
        else:
            all_text = f"No article content found on page {page}."

    except requests.exceptions.RequestException as e:
        all_text = f"Network error while crawling page {page}: {e}"

    return all_text

# ================== Function to Save to Google Sheet 1 ==================
def save_to_sheet(page):
    """Fetches article text and saves it to the first worksheet."""
    page = int(page) # Ensure page is an integer
    text = crawl_articles(page)
    if "error" in text.lower() or "not found" in text.lower():
        return f"Could not save to Google Sheet because: {text}"

    worksheet1.append_row([f"Page {page} Articles", text])
    return f"Successfully crawled and saved content from page {page} to '{WORKSHEET_NAME_1}'."

# ================== NEW: Function to Analyze and Save to Sheet 2 ==================
def analyze_and_save():
    """
    Reads all data from worksheet1, sends it to Gemini for analysis,
    and saves the result to worksheet2.
    """
    try:
        # 1. Read all data from the first worksheet
        all_values = worksheet1.get_all_values()
        if len(all_values) < 1:
            return "No data in '工作表1' to analyze.", ""

        # 2. Consolidate the text to be analyzed (from the second column)
        text_to_analyze = "\n\n---\n\n".join([row[1] for row in all_values if len(row) > 1])

        if not text_to_analyze.strip():
            return "Article content in '工作表1' is empty. Nothing to analyze.", ""

        # 3. Use the Gemini model to analyze the text with a detailed prompt
        prompt = f"""
        As a senior gaming community analyst, please analyze the following content from the Gamer.com.tw forum for 'MapleStory'.
        Your task is to provide a structured report covering:
        1.  **Summary of Topics**: Concisely summarize the core themes discussed in all articles.
        2.  **Key Issues & Sentiment**: Identify the key issues that players are most concerned about (e.g., class balance, event rewards, bugs, cheating) and analyze the general sentiment (positive, negative, or neutral) towards these issues.
        3.  **Emerging Trends**: Are there any new discussion trends or hot topics?
        4.  **Recommendations**: Based on your analysis, what specific advice would you give to the game's operations team?

        Please present your report in Traditional Chinese in a clear, well-organized format.

        ---
        Article Content:
        {text_to_analyze}
        ---
        """

        response = model.generate_content(prompt)
        analysis_result = response.text

        # 4. Save the analysis result to the second worksheet with a timestamp
        timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        worksheet2.append_row([f"Analysis Time: {timestamp}", analysis_result])

        return f"Analysis complete! Results have been saved to '{WORKSHEET_NAME_2}'.", analysis_result

    except Exception as e:
        error_message = f"An error occurred during analysis: {e}"
        return error_message, ""

# %%
analyze_and_save()
# Out:
# ("Analysis complete! Results have been saved to '工作表2'.",
#  '好的，作為資深遊戲社群分析師，我將針對您提供的Gamer.com.tw論壇內容進行分析。\n\n**重要提示：** 根據您提供的文章內容，文中提及的物品名稱、角色（如艾索德、愛莎、蕾娜、雷文、伊芙、澄、艾拉、愛利西斯、Add、露/希爾、蘿絲等）、副本名稱（如赫尼爾時空、秘密副本、英雄副本）以及冰裝系列等，都明確指向遊戲《艾爾之光》（Elsword），而非《楓之谷》（MapleStory）。因此，我的分析將基於這篇文章是關於《艾爾之光》的內容來進行。\n\n---\n\n### 《艾爾之光》Gamer.com.tw 論壇內容分析報告\n\n**報告日期：** 2023年10月27日\n**分析內容：** Gamer.com.tw 論壇玩家自製中韓物品對照表及相關討論\n\n---\n\n#### 1. 議題摘要 (Summary of Topics)\n\n此篇論壇文章的核心內容是由一位熱心玩家耗費大量時間，整理出一份極為詳盡的《艾爾之光》遊戲物品中韓文對照表。該對照表涵蓋了遊戲中的多種物品類別，包括特殊物品、公會相關、稱號、材料、艾爾結晶、強化道具、魔法石、副本掉落物、挫冰套裝、商城物品、時裝、技能切入圖、坐姿、臉部飾品、坐騎、寵物、Boss 箱子、水晶球、蘋果系列等。\n\n文章作者的目的在於幫助其他玩家識別物品、方便在買賣板上搜尋關鍵字進行交易，並指出谷歌翻譯的不足之處。留言區則圍繞著這份對照表，玩家們提出問題、尋求特定物品的韓文名稱、提供錯誤修正，或分享自己整理的補充資訊，顯示出社群高度的參與與互動。\n\n#### 2. 主要問題與玩家情緒 (Key Issues & Sentiment)\n\n1.  **物品名稱識別與跨語系溝通（主要問題，中性/正面情緒）：**\n    *   **問題：** 玩家在遊戲中，尤其是在與韓國版本內容相關的資訊交流、搜尋交易物品，或是新舊版本物品名稱翻譯不一致時，經常難以準確識別物品名稱或找到對應的關鍵字。原帖作者花費五小時整理對照表，以及留言區大量玩家請求特定物品韓文名稱，都強烈指出這是一個普遍且困擾玩家的問題。官方未提供類似的綜合性資源。\n    *   **情緒：** 玩家對作者的無私奉獻表達了高度的感謝與肯定（"大大辛苦了"），並積極參與補充和修正，展現了社群互助的正面氛圍。對於官方缺乏此類支援，則隱含著一種期待與無奈。\n\n2.  **遊戲機制與任務說明清晰度（次要問題，中性/輕微負面情緒）：**\n    *   **問題：** 某些玩家對遊戲內道具的用途（例如兩種+9捲軸的差異）、物品拆解的條件，以及特定任務的目標（例如「創造2轉任務4/5」的詳細條件）感到困惑，需要社群協助解惑。這可能指向遊戲內說明不足或翻譯上的歧義。\n    *   **情緒：** 玩家以提問方式尋求幫助，顯示了對這些機制的不解，可能略帶挫折感。\n\n3.  **內容資訊落差與更新速度（次要問題，中性/好奇情緒）：**\n    *   **問題：** 玩家關心某些服裝（如「FC足球連身裝」）或玩家設計立繪是否曾在韓版推出或未來是否會引入台版。這反映了玩家對遊戲內容，特別是跨地區內容差異和本地化進度的關注。\n    *   **情緒：** 玩家表達了對新內容的好奇和期待，但若資訊不透明或更新速度較慢，也可能轉為失望。\n\n**總體情緒：** 社群內部互助氛圍濃厚，玩家對彼此的幫助充滿感激。對於遊戲本身，玩家雖然有不解和需求，但主要表現為積極尋求解決方案而非強烈負面抱怨，這也歸因於熱心玩家提供了重要的社群支援。\n\n#### 3. 新興趨勢 (Emerging Trends)\n\n1.  **跨區內容交流日益頻繁：** 玩家對韓文翻譯的迫切需求，強烈暗示了他們積極參與韓版遊戲、參考韓版攻略資料，或與其他使用韓文名稱的玩家進行交流。這顯示玩家社群已超越單一伺服器的範疇，對於國際/韓國版本的遊戲內容有著高度的興趣和接觸。\n2.  **社群驅動的知識庫建立：** 當官方資訊不夠完善時，玩家社群展現出強大的自發性，投入大量時間精力，建立並維護關鍵的遊戲資料庫。這份中韓對照表就是一個典範，它透過集體協作不斷完善，成為玩家解決實際問題的重要工具。\n3.  **對「獨特/稀有」物品與技能的精準追求：** 玩家的提問從一般物品延伸到非常具體的時裝、坐姿、冰裝部件、王飾，甚至是特定技能的韓文名稱。這表明玩家在追求個性化外觀和最佳化戰力方面，需求越來越精準，並願意跨越語言障礙來獲取資訊。\n\n#### 4. 建議 (Recommendations)\n\n基於上述分析，以下是我對遊戲營運團隊的具體建議：\n\n1.  **建立並維護官方多語言（中、韓、英）遊戲物品/內容資料庫：**\n    *   **目標：** 徹底解決玩家在物品識別和跨語言溝通上的困擾，減少社群自發整理的負擔。\n    *   **執行：** 開發一個官方網站工具，提供可搜尋的物品、技能、稱號、時裝等資料庫，並提供中韓對照，甚至可加入英文。特別是針對遊戲內拍賣行或交易板，提供關鍵字提示或多語言搜尋功能。\n    *   **效益：** 大幅提升玩家體驗，降低新玩家進入門檻，增強老玩家的歸屬感和便利性。\n\n2.  **優化遊戲內說明與任務指引：**\n    *   **目標：** 提升遊戲機制的透明度和任務的清晰度，減少玩家困惑。\n    *   **執行：**\n        *   **改善道具說明：** 對於複雜道具（如強化捲軸），提供更詳盡的遊戲內文字說明或連結至教學頁面。\n        *   **審查任務翻譯與邏輯：** 定期審查重要任務（特別是轉職、史詩任務）的翻譯是否準確、目標是否清晰，避免因語言或條件模糊導致玩家卡關。考慮在任務介面提供更多提示或攻略連結。\n\n3.  **加強與社群內容創作者的互動與支援：**\n    *   **目標：** 肯定社群貢獻，將玩家熱情轉化為合作資源，提升營運效率。\n    *   **執行：**\n        *   **公開表彰：** 對於像本帖作者這樣為社群做出巨大貢獻的玩家，給予官方的公開表彰（例如論壇置頂、遊戲內稱號、少量虛寶獎勵）。\n        *   **合作機會：** 主動聯繫這些熱心玩家，徵詢他們將社群自製內容（如對照表）轉化為官方資源的可能性，或在官方資料庫建立時諮詢他們的意見和知識。\n\n4.  **提高對跨區內容的溝通透明度：**\n    *   **目標：** 滿足玩家對新內容的好奇心，管理玩家預期。\n    *   **執行：** 在官方社群平台或網站上，定期公布關於韓版特色內容（如玩家設計時裝、獨有活動）是否會引入台版的規劃，或說明兩地版本差異的原因。\n\n透過這些措施，營運團隊不僅能有效解決玩家當前的痛點，更能深化玩家對遊戲的投入和對營運團隊的信任，從而建立一個更加活躍和健康的社群生態。')

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# ================== Get or create worksheet3 ==================
WORKSHEET_NAME_3 = "工作表3"
try:
    worksheet3 = sh.worksheet(WORKSHEET_NAME_3)
except gspread.WorksheetNotFound:
    worksheet3 = sh.add_worksheet(title=WORKSHEET_NAME_3, rows="1000", cols="3")

# ================== TF-IDF / 熱詞統計函數 ==================
def tfidf_analysis_to_sheet(top_n=20):
    """
    從工作表1讀取文章內容，計算詞頻和TF-IDF，存到工作表3
    top_n: 取前N個熱詞
    """
    try:
        # 1. 讀取工作表1所有文章
        all_values = worksheet1.get_all_values()
        if len(all_values) < 1:
            return "工作表1沒有資料可以分析。"

        texts = [row[1] for row in all_values if len(row) > 1 and row[1].strip()]
        if not texts:
            return "文章內容為空，無法分析。"

        # 2. 使用 TF-IDF 計算詞頻
        vectorizer = TfidfVectorizer(
            stop_words=None,   # 可以自訂中文停用詞
            max_features=1000  # 只保留前1000個詞
        )
        tfidf_matrix = vectorizer.fit_transform(texts)
        feature_names = vectorizer.get_feature_names_out()

        # 3. 計算每個詞的總 TF-IDF 分數
        tfidf_sum = tfidf_matrix.sum(axis=0)
        tfidf_scores = [(word, tfidf_sum[0, idx]) for idx, word in enumerate(feature_names)]
        tfidf_scores.sort(key=lambda x: x[1], reverse=True)

        # 4. 取前 top_n 熱詞
        top_words = tfidf_scores[:top_n]

        # 5. 清空工作表3後寫入
        worksheet3.clear()
        worksheet3.append_row(["詞語", "TF-IDF 分數"])
        for word, score in top_words:
            worksheet3.append_row([word, score])

        return f"TF-IDF 熱詞分析完成，前 {top_n} 熱詞已寫入 '{WORKSHEET_NAME_3}'。"

    except Exception as e:
        return f"分析過程中發生錯誤: {e}"

# %%
tfidf_analysis_to_sheet(top_n=20)
# Out:
# "TF-IDF 熱詞分析完成，前 20 熱詞已寫入 '工作表3'。"

# %% [markdown]
# gradio不另示範，可以按照自己步調處理窩，詳情可參考作業2解決gradio的問題~~嘿嘿
